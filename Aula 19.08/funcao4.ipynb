# %%
def cadastrar_produtos():
    produto = input('Digite o nome do produto a ser cadastrado: ').casefold()
    print(f'O produto {produto} foi cadastrado com sucesso ! 👌')

cadastrar_produtos()
# Out:
# O produto feijao foi cadastrado com sucesso ! 👌
