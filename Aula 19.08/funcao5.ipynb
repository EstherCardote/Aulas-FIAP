# %%
def cadastrar_produtos():
    produto = input('Digite o nome do produto a ser cadastrado: ').casefold().strip() #Strip tira os espaços em branco antes e depois da palavra
    print(f'O produto {produto} foi cadastrado com sucesso ! 👌')
    return produto

produto = cadastrar_produtos()

print(produto)
# Out:
# O produto arroz foi cadastrado com sucesso ! 👌
# arroz
