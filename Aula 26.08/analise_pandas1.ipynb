# %%
import pandas as pd

# %%
clientes_df = pd.read_csv('Clientes.csv', sep=';')
lojas_df = pd.read_csv('Lojas.csv', sep=';')
produtos_df = pd.read_csv('Produtos.csv', sep=';')
promocoes_df = pd.read_csv('Promocoes.csv', sep=';')
vendas_df = pd.read_csv('Vendas2017.csv', sep=';')

# %%
# Exibindo os conteudos das bases de dados
vendas_df
produtos_df
# Out:
#          Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0              Contoso  Econômico          10,69          20,96         873
# 1              Contoso  Econômico           6,63             13         879
# 2              Contoso  Econômico           6,63             13         880
# 3              Contoso  Econômico           6,63             13         881
# 4              Contoso  Econômico           6,63             13         882
# ...                ...        ...            ...            ...         ...
# 1685  Southridge Video    Regular          82,77         179,99        1602
# 1686  Southridge Video    Regular          73,57         159,99        1606
# 1687  Southridge Video    Regular          82,77         179,99        1607
# 1688  Southridge Video    Regular          73,57         159,99        1611
# 1689  Southridge Video    Regular          82,77         179,99        1612
#
#                       Categoria
# ...

# %%
lojas_df.columns
# Out:
# Index(['ID Loja', 'Nome da Loja', 'Quantidade Colaboradores', 'País'], dtype='str')

# %%
clientes_df = clientes_df[['ID Cliente','E-mail']]
produtos_df = produtos_df[['ID Produto','Categoria']]
lojas_df = lojas_df[['ID Loja','Nome da Loja']]

# %%
# Mesclando os DataFrames
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')

display(vendas_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df.head()
# Out:
#    Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  ID Produto  \
# 0                1    01/01/2017    02/01/2017         1       86         981
# 1                2    01/01/2017    06/01/2017         5      308        1586
# 2                3    01/01/2017    01/01/2017         0      294        1444
# 3                4    01/01/2017    01/01/2017         0      251        1468
# 4                5    01/01/2017    07/01/2017         6       94        1106
#
#    ID Promocao  ID Cliente  Quantidade Vendida  Quantidade Devolvida  \
# 0            2        6825                   9                     1
# 1            2       18469                   9                     1
# 2            5       19730                  13                     1
# 3            5       29326                   6                     1
# 4            2       22617                   4                     1
#
#           Categoria_x                       Nome da Loja_x  \
# ...

# %%
# Quantas vezes o cliente comprou com a empresa
frequencia_cliente = vendas_df['E-mail'].value_counts()
display(frequencia_cliente)

frequencia_cliente.plot()
# Out:
# E-mail
# karen33@adventure-works.com      77
# chloe77@adventure-works.com      74
# julia43@adventure-works.com      69
# destiny66@adventure-works.com    68
# karen16@adventure-works.com      68
#                                  ..
# ckilfoyle88@yahoo.co.jp           1
# pmcgaheylk@nbcnews.com            1
# osaffleev@hao123.com              1
# mtrimmill2d@abc.net.au            1
# clifford8@adventure-works.com     1
# Name: count, Length: 38907, dtype: int64
# <Axes: xlabel='E-mail'>

# %%
import matplotlib as mp

# %%
frequencia_cliente[:5].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='E-mail'>

# %%
# A loja que mais fez venda
frequencia_vendas = vendas_df[['ID Loja','Nome da Loja_x']].value_counts()
display(frequencia_vendas)

frequencia_vendas.plot()
# Out:
# ID Loja  Nome da Loja_x
# 200      Loja Contoso Catalog                   47324
# 306      Loja Contoso Europe Online             42771
# 199      Loja Contoso North America Online      42722
# 307      Loja Contoso Asia Online               37502
# 308      Loja Contoso North America Reseller    35353
#                                                 ...
# 280      Loja Contoso Guangzhou                    41
# 273      Loja Contoso Kyoto                        40
# 133      Loja Contoso Paterson                     37
# 223      Loja Contoso Venezia                      29
# 65       Loja Contoso Racine No.2                  24
# Name: count, Length: 306, dtype: int64
# <Axes: xlabel='ID Loja,Nome da Loja_x'>

# %%
frequencia_vendas[:5].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='ID Loja,Nome da Loja_x'>

# %%
# Categoria que mais fez venda
frequencia_categoria = vendas_df['Categoria_x'].value_counts()
display(frequencia_categoria)

frequencia_categoria.plot()
# Out:
# Categoria_x
# Acessório para Computador            106578
# Câmera Digital SLR                    73314
# Câmera Digital                        72648
# Impressora, Scanner & Fax             72148
# Câmera e Filmadora                    66486
# Telefone para Casa & Escritório       66170
# Projetor                              60834
# Filme DVD                             60581
# Tablet                                59596
# Home Theater                          49966
# Smartphone                            43061
# Monitor                               38767
# Acessório para Câmera                 35988
# Sistema Audivisual para Carro         34714
# Laptop                                26902
# Desktop                               26688
# Televisão                             22643
# Acessórios para Telefone & Tablet     15860
# Aparelho de Som                       14785
# Fone de Ouvido Bluetooth              14443
# DVD                                   12521
# ...

# %%
frequencia_categoria[:5].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Categoria_x'>
